# %% [markdown]
# # Declarações

# %%
# !pip install basedosdados
import basedosdados as bd
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns
import scipy.stats as sp
# Out:
# Requirement already satisfied: basedosdados in c:\users\lenovo\anaconda3\lib\site-packages (1.5.7)
# Requirement already satisfied: pandas==1.2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (1.2.4)
# Requirement already satisfied: google-cloud-storage==1.31.2 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (1.31.2)
# Requirement already satisfied: pyaml==20.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (20.4.0)
# Requirement already satisfied: tomlkit==0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (0.7.0)
# Requirement already satisfied: google-cloud-bigquery==1.28.0 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (1.28.0)
# Requirement already satisfied: pandas-gbq==0.13.2 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (0.13.2)
# Requirement already satisfied: tqdm==4.50.2 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (4.50.2)
# Requirement already satisfied: ruamel.yaml==0.17.4 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (0.17.4)
# Requirement already satisfied: click==7.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (7.1.2)
# Requirement already satisfied: google-cloud-bigquery-storage==1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (1.1.0)
# Requirement already satisfied: Jinja2==2.11.2 in c:\users\lenovo\anaconda3\lib\site-packages (from basedosdados) (2.11.2)
# Requirement already satisfied: google-api-core<2.0dev,>=1.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-bigquery==1.28.0->basedosdados) (1.33.2)
# Requirement already satisfied: google-resumable-media<2.0dev,>=0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-bigquery==1.28.0->basedosdados) (1.3.3)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-bigquery==1.28.0->basedosdados) (1.7.3)
# Requirement already satisfied: six<2.0.0dev,>=1.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-bigquery==1.28.0->basedosdados) (1.15.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-storage==1.31.2->basedosdados) (1.35.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-cloud-storage==1.31.2->basedosdados) (2.25.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lenovo\anaconda3\lib\site-packages (from Jinja2==2.11.2->basedosdados) (1.1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas==1.2.4->basedosdados) (1.19.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas==1.2.4->basedosdados) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas==1.2.4->basedosdados) (2.8.1)
# Requirement already satisfied: google-auth-oauthlib in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-gbq==0.13.2->basedosdados) (0.5.3)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-gbq==0.13.2->basedosdados) (52.0.0.post20210125)
# Requirement already satisfied: pydata-google-auth in c:\users\lenovo\anaconda3\lib\site-packages (from pandas-gbq==0.13.2->basedosdados) (1.7.0)
# Requirement already satisfied: PyYAML in c:\users\lenovo\anaconda3\lib\site-packages (from pyaml==20.4.0->basedosdados) (5.4.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from ruamel.yaml==0.17.4->basedosdados) (0.2.7)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery==1.28.0->basedosdados) (1.58.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery==1.28.0->basedosdados) (3.20.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery==1.28.0->basedosdados) (1.51.3)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in c:\users\lenovo\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery==1.28.0->basedosdados) (1.48.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.31.2->basedosdados) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.31.2->basedosdados) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.31.2->basedosdados) (4.2.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-resumable-media<2.0dev,>=0.6.0->google-cloud-bigquery==1.28.0->basedosdados) (1.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage==1.31.2->basedosdados) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.31.2->basedosdados) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.31.2->basedosdados) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.31.2->basedosdados) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage==1.31.2->basedosdados) (4.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo\anaconda3\lib\site-packages (from google-auth-oauthlib->pandas-gbq==0.13.2->basedosdados) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas-gbq==0.13.2->basedosdados) (3.2.2)

# %% [markdown]
# # ENEM para IDEP

# %% [markdown]
# ## Importando base de dados

# %%
enem_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019.csv', sep = ',',
                        usecols = ['treineiro', 'nota_lc', 'nota_mt', 'nota_redacao', 'estado'],
                        skiprows = lambda i: i > 0 and random.random() > 0.1)

# %% [markdown]
# ## Removendo treineiros

# %%
enem_2019 = enem_2019.drop(enem_2019[enem_2019.treineiro == 1].index) #removendo os treineiros ;)
enem_2019.query('treineiro == 1')

# %%
enem_2019.drop(columns = 'treineiro', inplace = True)
enem_2019.sample(10)

# %% [markdown]
# ## Exportando a base de dados tratada

# %%
enem_2019.dropna(inplace = True)
enem_2019.describe()
enem_2019.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019_idep.csv',
                           sep=';', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Importando base de dados tratada

# %%
enem_2019_idep = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019_idep.csv',
                           sep=';', encoding='utf-8-sig')

# %% [markdown]
# ## Organizando por estado e deixando apropriado para comparar com a base do IDEP

# %%
enem_2019_idep_uf = enem_2019_idep.groupby('estado')
enem_2019_idep_uf.mean()

# %%
df_enem_2019_idep_uf = enem_2019_idep_uf.mean().reset_index()
df_enem_2019_idep_uf.rename(columns={'estado': 'sigla_uf'}, inplace=True)
df_enem_2019_idep_uf

# %% [markdown]
# # IDEP

# %% [markdown]
# ## Importando a base do IDEB

# %%
idep_uf = bd.read_table(dataset_id='br_inep_ideb', table_id='uf', billing_project_id="analytica-desigualdade")

# %% [markdown]
# ## Tratando os dados

# %%
idep_uf.drop(columns = "indicador_rendimento", inplace = True) #é a mesma coisa que a taxa de aprovação!

# %%
idep_uf_2019 = idep_uf.query("ano == 2019").drop(columns = 'ano')
idep_2019_total = idep_uf_2019.query("rede == 'total'").drop(columns = 'rede')
idep_2019_fundamentalI = idep_2019_total.query("anos_escolares == 'finais (6-9)'").drop(columns = ['anos_escolares', 'ensino'])
idep_2019_fundamentalII = idep_2019_total.query("anos_escolares == 'iniciais (1-5)'").drop(columns = ['anos_escolares', 'ensino'])
idep_2019_medio = idep_2019_total.query("anos_escolares == 'todos (1-4)'").drop(columns = ['anos_escolares', 'ensino'])

# %% [markdown]
# ## Exportando as base de dados tratadas

# %%
idep_2019_fundamentalI.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalI_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')
idep_2019_fundamentalII.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalII_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')
idep_2019_medio.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_medio_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Importando as bases de dados tratadas

# %%
idep_2019_fundamentalI = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalI_2019.csv',
                                     sep=';')
idep_2019_fundamentalII = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalII_2019.csv',
                           sep=';')
idep_2019_medio = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_medio_2019.csv',
                           sep=';')

# %% [markdown]
# # Unindo os datasets

# %%
idep_2019_fundamentalI_mat  = idep_2019_fundamentalI.loc[:, ['sigla_uf', 'nota_saeb_matematica']].reset_index().drop(columns = 'index')
idep_2019_fundamentalII_mat = idep_2019_fundamentalII.loc[:, ['sigla_uf', 'nota_saeb_matematica']].reset_index().drop(columns = 'index')
idep_2019_medio_mat         = idep_2019_medio.loc[:, ['sigla_uf', 'nota_saeb_matematica']].reset_index().drop(columns = 'index')
df_enem_2019_cat_renda_por_uf_mat = df_enem_2019_cat_renda_por_uf.loc[:, ['sigla_uf', 'nota_mt']]
matematica_2019 = pd.merge(idep_2019_fundamentalI_mat, idep_2019_fundamentalII_mat, on='sigla_uf')
matematica_2019 = pd.merge(matematica_2019, idep_2019_medio_mat, on='sigla_uf')
matematica_2019 = pd.merge(matematica_2019, df_enem_2019_cat_renda_por_uf_mat, on='sigla_uf')
matematica_2019.rename(columns = {'nota_saeb_matematica_x': 'nota_saeb_fundamentalI', 'nota_saeb_matematica_y': 'nota_saeb_fundamentalII',
                                 'nota_saeb_matematica': 'nota_saeb_medio', 'nota_mt': 'enem'}, inplace=True)
matematica_2019

# %%
idep_2019_fundamentalI_por  = idep_2019_fundamentalI.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
idep_2019_fundamentalII_por = idep_2019_fundamentalII.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
idep_2019_medio_por         = idep_2019_medio.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
df_enem_2019_cat_renda_por_uf_port = df_enem_2019_cat_renda_por_uf.loc[:, ['sigla_uf', 'nota_lc']]
portugues_2019 = pd.merge(idep_2019_fundamentalI_por, idep_2019_fundamentalII_por, on='sigla_uf')
portugues_2019 = pd.merge(portugues_2019, idep_2019_medio_por, on='sigla_uf')
portugues_2019 = pd.merge(portugues_2019, df_enem_2019_cat_renda_por_uf_port, on='sigla_uf')
portugues_2019.rename(columns = {'nota_saeb_lingua_portuguesa_x': 'nota_saeb_fundamentalI', 'nota_saeb_lingua_portuguesa_y': 'nota_saeb_fundamentalII',
                                 'nota_saeb_lingua_portuguesa': 'nota_saeb_medio', 'nota_lc': 'enem'}, inplace=True)
portugues_2019

# %%
idep_2019_fundamentalI_por  = idep_2019_fundamentalI.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
idep_2019_fundamentalII_por = idep_2019_fundamentalII.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
idep_2019_medio_por         = idep_2019_medio.loc[:, ['sigla_uf', 'nota_saeb_lingua_portuguesa']].reset_index().drop(columns = 'index')
df_enem_2019_cat_renda_por_uf_red = df_enem_2019_cat_renda_por_uf.loc[:, ['sigla_uf', 'nota_redacao']]
portugues_2019 = pd.merge(idep_2019_fundamentalI_por, idep_2019_fundamentalII_por, on='sigla_uf')
portugues_2019 = pd.merge(portugues_2019, idep_2019_medio_por, on='sigla_uf')
redacao_2019 = pd.merge(portugues_2019, df_enem_2019_cat_renda_por_uf_red, on='sigla_uf')
redacao_2019.rename(columns = {'nota_saeb_lingua_portuguesa_x': 'nota_saeb_fundamentalI', 'nota_saeb_lingua_portuguesa_y': 'nota_saeb_fundamentalII',
                                 'nota_saeb_lingua_portuguesa': 'nota_saeb_medio', 'nota_redacao': 'enem'}, inplace=True)
redacao_2019

# %% [markdown]
# ## Exportando as bases de dados

# %%
portugues_2019.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\portugues_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')
matematica_2019.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\matematica_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')
redacao_2019.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\redacao_2019.csv',
                           sep=';', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Importando as bases de dados

# %%
portugues_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\portugues_2019.csv',
                           sep=';')
matematica_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\matematica_2019.csv',
                           sep=';')
redacao_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\redacao_2019.csv',
                           sep=';')

# %% [markdown]
# ## Explorando as bases de dados

# %%
portugues_2019.corr() 
#base importa muito! mas quanto mais próximo, mais correlação esses dois exames têm em português, embora menos que matemática
#em todos os casos, a correlação é forte!

# %%
plt.matshow(portugues_2019.corr())
plt.show()

# %%
matematica_2019.corr() 
#base importa muito! mas quanto mais próximo, mais correlação esses dois exames têm em matemática. 
#em todos os casos a correlação é forte!

# %%
plt.matshow(matematica_2019.corr())
plt.show()

# %%
redacao_2019.corr() #redação não tem tanta correlação com estudar português - correlação moderada (!!!)

# %%
plt.matshow(redacao_2019.corr())
plt.show()

# %% [markdown]
# ### Conclusão: Estudo de base sólido tem uma correlação forte no desempenho do enem. Naturalmente, quão mais próximas temporamente elas forem, mais forte será o impacto. Vemos que isso especialmente se dá em matemática, que é uma matéria cheia de pré-requisitos, os quais sem eles, o aluno pode se perder conforme o tempo passa e não só se desinteressar na matéria, mas também não assimilar novos conhecimentos. Embora o português não tenha esse caráter, ainda é de forte correlação o quanto o estado dedica nos ensinos primários e seu desempenho no ENEM. Finalmente, o estudo de base em português tem uma correlação moderada com as notas de redação do ENEM; talvez isso se dê pelo fato da redação do ENEM ter como apenas uma competência a gramática, representando 1/5 da nota. De forma geral, o resumo é que aqueles estados que se dedicam nos ensinos de base são recompensados com boas notas no ENEM.

# %% [markdown]
# # Explorando a base de dados do IDEP

# %% [markdown]
# ## Importando as base de dados tratadas

# %%
idep_2019_fundamentalI = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalI_2019.csv',
                                     sep=';')
idep_2019_fundamentalII = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_fundamentalII_2019.csv',
                           sep=';')
idep_2019_medio = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\idep_medio_2019.csv',
                           sep=';')

# %%
idep_2019_fundamentalI.boxplot('taxa_aprovacao')

# %%
idep_2019_fundamentalII.boxplot('taxa_aprovacao')

# %%
idep_2019_medio.boxplot('taxa_aprovacao')

# %% [markdown]
# ### Não há outliers!

# %%
idep_2019_fundamentalI_sorted = idep_2019_fundamentalI.sort_values("taxa_aprovacao")

plt.rc('figure', figsize = (20, 10))

fig = plt.bar(idep_2019_fundamentalI_sorted['sigla_uf'], idep_2019_fundamentalI_sorted['taxa_aprovacao'])
plt.ylabel("Taxa de aprovação (%)", fontsize = 30)
plt.title("Taxa de aprovação do IDEP fundamental I por estado", fontsize = 40, pad = 20)

# %%
idep_2019_fundamentalII_sorted = idep_2019_fundamentalII.sort_values("taxa_aprovacao")

plt.bar(idep_2019_fundamentalII_sorted['sigla_uf'], idep_2019_fundamentalII_sorted['taxa_aprovacao'])
plt.ylabel("Taxa de aprovação (%)", fontsize = 30)
plt.title("Taxa de aprovação do IDEP fundamental II por estado", fontsize = 40, pad = 20)

# %%
idep_2019_medio_sorted = idep_2019_medio.sort_values("taxa_aprovacao")

fig = plt.gcf()

fig.set_size_inches(18.5, 10.5)
plt.bar(idep_2019_medio_sorted['sigla_uf'], idep_2019_medio_sorted['taxa_aprovacao'])
plt.ylabel("Taxa de aprovação (%)", fontsize = 30)
plt.title("Taxa de aprovação do IDEP no ensino médio por estado", fontsize = 35, pad = 20)

# %% [markdown]
# # Explorando a base de dados do ENEM por gênero

# %% [markdown]
# ## Importando base de dados

# %%
enem_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019.csv', sep = ',',
                        usecols = ['sexo', 'treineiro', 'nota_lc', 'nota_mt', 'nota_ct', 'nota_ch', 'estado'],
                        skiprows = lambda i: i > 0 and random.random() > 0.1)

# %% [markdown]
# ## Removendo os treineiros e padronizando o nome das colunas

# %%
enem_2019 = enem_2019.drop(enem_2019[enem_2019.treineiro == 1].index) #removendo os treineiros ;)
enem_2019 = enem_2019.drop(columns = 'treineiro').rename(columns = {'estado': 'sigla_uf'}).dropna()
enem_2019
# Out:
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf
# 2         F    463.6    417.3    431.0    397.9       PA
# 3         F    503.2    546.7    551.8    436.8       PA
# 5         F    343.8    481.0    499.5    397.6       PA
# 6         F    414.8    388.2    457.6    401.6       PA
# 7         F    557.8    550.1    528.0    418.5       PA
# ...     ...      ...      ...      ...      ...      ...
# 509188    M    516.9    553.7    516.2    519.0       BA
# 509193    M    429.2    446.8    479.9    423.0       MG
# 509196    F    509.9    570.7    562.3    596.9       MG
# 509197    F    363.4    527.8    547.0    516.9       MG
# 509198    F    454.2    542.7    599.3    504.7       BA
#
# [316524 rows x 6 columns]

# %% [markdown]
# ## Agrupando por gênero

# %%
enem_2019['media'] = (enem_2019.nota_ct + enem_2019.nota_ch + enem_2019.nota_mt + enem_2019.nota_lc)/4
enem_2019
# Out:
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf    media
# 2         F    463.6    417.3    431.0    397.9       PA  427.450
# 3         F    503.2    546.7    551.8    436.8       PA  509.625
# 5         F    343.8    481.0    499.5    397.6       PA  430.475
# 6         F    414.8    388.2    457.6    401.6       PA  415.550
# 7         F    557.8    550.1    528.0    418.5       PA  513.600
# ...     ...      ...      ...      ...      ...      ...      ...
# 509188    M    516.9    553.7    516.2    519.0       BA  526.450
# 509193    M    429.2    446.8    479.9    423.0       MG  444.725
# 509196    F    509.9    570.7    562.3    596.9       MG  559.950
# 509197    F    363.4    527.8    547.0    516.9       MG  488.775
# 509198    F    454.2    542.7    599.3    504.7       BA  525.225
#
# [316524 rows x 7 columns]

# %%
ax = sns.displot(enem_2019_genero['media'], height=8, kind='kde', hue=enem_2019_genero.sigla_uf)

ax.set(title ='Distribuição de frequência da renda mensal', 
       xlabel='Categoria da renda mensal', ylabel='Quantidade de participantes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f59f8427c2d9> in <module>
# ----> 1 ax = sns.displot(enem_2019_genero['media'], height=8, kind='kde', hue=enem_2019_genero.sigla_uf)
#       2
#       3 ax.set(title ='Distribuição de frequência da renda mensal',
#       4        xlabel='Categoria da renda mensal', ylabel='Quantidade de participantes')
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2145 ):
#    2146
# -> 2147     p = _DistributionFacetPlotter(
#    2148         data=data,
#    2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     660         if x is None and y is None:
#     661             self.input_format = "wide"
# --> 662             plot_data, variables = self._assign_variables_wideform(
#     663                 data, **variables,
#     664             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in _assign_variables_wideform(self, data, **kwargs)
#     709             err = f"The following variable{s} cannot be assigned with wide-form data: "
#     710             err += ", ".join(f"`{v}`" for v in assigned)
# --> 711             raise ValueError(err)
#     712
#     713         # Determine if the data object actually has any data in it
#
# ValueError: The following variable cannot be assigned with wide-form data: `hue`

# %%
enem_2019_genero = enem_2019.groupby(by='sexo')

# %%
for item, sexo in enem_2019_genero:
    print(enem_2019_genero.get_group(item))
# Out:
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf    media
# 2         F    463.6    417.3    431.0    397.9       PA  427.450
# 3         F    503.2    546.7    551.8    436.8       PA  509.625
# 5         F    343.8    481.0    499.5    397.6       PA  430.475
# 6         F    414.8    388.2    457.6    401.6       PA  415.550
# 7         F    557.8    550.1    528.0    418.5       PA  513.600
# ...     ...      ...      ...      ...      ...      ...      ...
# 509185    F    409.6    422.5    497.4    463.1       BA  448.150
# 509187    F    454.0    459.5    524.4    387.8       BA  456.425
# 509196    F    509.9    570.7    562.3    596.9       MG  559.950
# 509197    F    363.4    527.8    547.0    516.9       MG  488.775
# 509198    F    454.2    542.7    599.3    504.7       BA  525.225
#
# [186555 rows x 7 columns]
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf    media
# 9         M    454.6    418.1    393.7    443.2       PA  427.400
# 16        M    454.2    592.8    555.6    551.9       PA  538.625
# 20        M    419.4    411.5    523.6    426.4       PA  445.225
# 26        M    530.9    646.2    628.5    578.3       PA  595.975
# 30        M    513.0    548.4    536.7    573.0       PA  542.775
# ...     ...      ...      ...      ...      ...      ...      ...
# 509177    M    502.1    522.0    466.4    435.1       BA  481.400
# 509179    M    470.4    500.3    508.9    403.2       BA  470.700
# 509180    M    446.0    420.9    554.9    400.0       BA  455.450
# 509188    M    516.9    553.7    516.2    519.0       BA  526.450
# 509193    M    429.2    446.8    479.9    423.0       MG  444.725
#
# [129969 rows x 7 columns]

# %%
ax = sns.displot(enem_2019_renda['renda_mensal_familiar'], height=8, kind='kde', )

ax.set(title ='Distribuição de frequência da renda mensal', 
       xlabel='Categoria da renda mensal', ylabel='Quantidade de participantes')

# %% [markdown]
# # Separar os datasets em M e F

# %% [markdown]
# # Número médio de horas semanais dedicadas aos cuidados de pessoas e/ou afazeres domésticos das pessoas de 14 anos ou mais de idade ocupadas na semana de referência por sexo segundo Unidades da Federação

# %%
trabalho_domestico = pd.read_excel(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\horas_dedicadas_trabalho_domestico.xlsx')

# %%
trabalho_domestico_total = trabalho_domestico.loc[:, ['sigla_uf', 'M', 'F']].drop([27], 0).reset_index().drop(columns = 'index').set_index('sigla_uf')
trabalho_domestico_total
# Out:
#                   M          F
# sigla_uf
# RO        10.455863  17.276939
# AC        11.293393  18.125120
# AM        10.135388  15.302833
# RR        10.481230  16.770360
# PA        11.126516  20.677165
# AP        11.546557  15.814292
# TO        10.393480  17.072275
# MA        10.348905  18.691639
# PI        10.458465  20.612829
# CE         9.921540  18.998320
# RN         9.261115  18.349723
# PB        11.495809  22.425116
# PE        10.390543  18.809256
# AL        11.143170  18.799776
# SE         9.689595  20.363867
# BA         9.380534  18.276909
# MG        10.508886  19.894315
# ES        10.931464  18.933027
# RJ        11.593414  18.314045
# SP        10.492274  18.475385
# PR        10.600087  18.057808
# SC        10.708067  17.448903
# RS        10.749080  17.553784
# MS         9.517217  17.102543
# MT         8.801510  16.341790
# GO         8.804934  16.724892
# DF        10.572553  17.218828

# %% [markdown]
# # Unindo bases de dados

# %%
relacao_nota_trabalho_domestico = enem_2019.merge(trabalho_domestico_total, on='sigla_uf')
relacao_nota_trabalho_domestico
# Out:
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf    media          M  \
# 0         F    463.6    417.3    431.0    397.9       PA  427.450  11.126516
# 1         F    503.2    546.7    551.8    436.8       PA  509.625  11.126516
# 2         F    343.8    481.0    499.5    397.6       PA  430.475  11.126516
# 3         F    414.8    388.2    457.6    401.6       PA  415.550  11.126516
# 4         F    557.8    550.1    528.0    418.5       PA  513.600  11.126516
# ...     ...      ...      ...      ...      ...      ...      ...        ...
# 316519    F    473.3    555.6    552.3    640.1       DF  555.325  10.572553
# 316520    M    450.7    512.5    494.6    372.0       DF  457.450  10.572553
# 316521    F    528.0    531.7    584.3    413.4       DF  514.350  10.572553
# 316522    F    469.5    422.4    516.2    392.6       DF  450.175  10.572553
# 316523    F    427.0    508.7    507.8    429.9       DF  468.350  10.572553
#
#                 F
# 0       20.677165
# 1       20.677165
# 2       20.677165
# 3       20.677165
# 4       20.677165
# ...           ...
# 316519  17.218828
# 316520  17.218828
# 316521  17.218828
# 316522  17.218828
# 316523  17.218828
#
# [316524 rows x 9 columns]

# %%
relacao_nota_trabalho_domestico['horas_semanais_trabalho_domestico'] = np.where(relacao_nota_trabalho_domestico['sexo'] == 'M', 
                                                                                relacao_nota_trabalho_domestico['M'], 
                                                                                relacao_nota_trabalho_domestico['F'])
relacao_nota_trabalho_domestico.drop(columns = ['M','F'], inplace=True)

# %%
relacao_nota_trabalho_domestico
# Out:
#        sexo  nota_ct  nota_ch  nota_lc  nota_mt sigla_uf    media  \
# 0         F    463.6    417.3    431.0    397.9       PA  427.450
# 1         F    503.2    546.7    551.8    436.8       PA  509.625
# 2         F    343.8    481.0    499.5    397.6       PA  430.475
# 3         F    414.8    388.2    457.6    401.6       PA  415.550
# 4         F    557.8    550.1    528.0    418.5       PA  513.600
# ...     ...      ...      ...      ...      ...      ...      ...
# 316519    F    473.3    555.6    552.3    640.1       DF  555.325
# 316520    M    450.7    512.5    494.6    372.0       DF  457.450
# 316521    F    528.0    531.7    584.3    413.4       DF  514.350
# 316522    F    469.5    422.4    516.2    392.6       DF  450.175
# 316523    F    427.0    508.7    507.8    429.9       DF  468.350
#
#         horas_semanais_trabalho_domestico
# 0                               20.677165
# 1                               20.677165
# 2                               20.677165
# 3                               20.677165
# 4                               20.677165
# ...                                   ...
# 316519                          17.218828
# 316520                          10.572553
# 316521                          17.218828
# 316522                          17.218828
# 316523                          17.218828
#
# [316524 rows x 8 columns]

# %%
relacao_nota_trabalho_domestico.groupby("sigla_uf").corr().query('horas_semanais_trabalho_domestico == 1.0')
# Out:
#                                              nota_ct   nota_ch   nota_lc  \
# sigla_uf
# AC       horas_semanais_trabalho_domestico -0.135647 -0.087720 -0.001727
# AL       horas_semanais_trabalho_domestico -0.147161 -0.105282 -0.047737
# AM       horas_semanais_trabalho_domestico -0.131163 -0.071844  0.007515
# AP       horas_semanais_trabalho_domestico -0.154838 -0.056373 -0.006982
# BA       horas_semanais_trabalho_domestico -0.136283 -0.104299 -0.042256
# CE       horas_semanais_trabalho_domestico -0.106384 -0.059981 -0.001530
# DF       horas_semanais_trabalho_domestico -0.158406 -0.105492 -0.039198
# ES       horas_semanais_trabalho_domestico -0.129174 -0.073789 -0.008759
# GO       horas_semanais_trabalho_domestico -0.113210 -0.051738  0.006234
# MA       horas_semanais_trabalho_domestico -0.136620 -0.070324 -0.003709
# MG       horas_semanais_trabalho_domestico -0.126939 -0.093403 -0.022359
# MS       horas_semanais_trabalho_domestico -0.149616 -0.130598 -0.045130
# MT       horas_semanais_trabalho_domestico -0.109867 -0.058121  0.005743
# PA       horas_semanais_trabalho_domestico -0.136495 -0.076003 -0.008464
# PB       horas_semanais_trabalho_domestico -0.157341 -0.121087 -0.056606
# PE       horas_semanais_trabalho_domestico -0.120226 -0.090238 -0.025912
# PI       horas_semanais_trabalho_domestico -0.112555 -0.071057  0.000871
# PR       horas_semanais_trabalho_domestico -0.115179 -0.068840  0.006716
# RJ       horas_semanais_trabalho_domestico -0.128977 -0.115391 -0.053086
# RN       horas_semanais_trabalho_domestico -0.152379 -0.121738 -0.059845
# RO       horas_semanais_trabalho_domestico -0.105441 -0.065925  0.004433
# RR       horas_semanais_trabalho_domestico -0.154455 -0.130135 -0.031787
# RS       horas_semanais_trabalho_domestico -0.115720 -0.087407 -0.018882
# SC       horas_semanais_trabalho_domestico -0.135415 -0.085468 -0.012949
# SE       horas_semanais_trabalho_domestico -0.108241 -0.123835 -0.055304
# SP       horas_semanais_trabalho_domestico -0.123107 -0.086994 -0.025893
# TO       horas_semanais_trabalho_domestico -0.154316 -0.088246 -0.016559
#
#                                              nota_mt     media  \
# sigla_uf
# AC       horas_semanais_trabalho_domestico -0.171168 -0.130733
# AL       horas_semanais_trabalho_domestico -0.198364 -0.158477
# AM       horas_semanais_trabalho_domestico -0.163245 -0.117718
# AP       horas_semanais_trabalho_domestico -0.182604 -0.129177
# BA       horas_semanais_trabalho_domestico -0.204743 -0.155556
# CE       horas_semanais_trabalho_domestico -0.161586 -0.107187
# DF       horas_semanais_trabalho_domestico -0.204859 -0.159762
# ES       horas_semanais_trabalho_domestico -0.184113 -0.130432
# GO       horas_semanais_trabalho_domestico -0.174972 -0.111429
# MA       horas_semanais_trabalho_domestico -0.185192 -0.129721
# MG       horas_semanais_trabalho_domestico -0.190095 -0.140288
# MS       horas_semanais_trabalho_domestico -0.203886 -0.168107
# MT       horas_semanais_trabalho_domestico -0.162077 -0.108520
# PA       horas_semanais_trabalho_domestico -0.186427 -0.132581
# PB       horas_semanais_trabalho_domestico -0.220935 -0.176870
# PE       horas_semanais_trabalho_domestico -0.192223 -0.139349
# PI       horas_semanais_trabalho_domestico -0.175589 -0.116972
# PR       horas_semanais_trabalho_domestico -0.194500 -0.126964
# RJ       horas_semanais_trabalho_domestico -0.207584 -0.161834
# RN       horas_semanais_trabalho_domestico -0.226148 -0.177264
# RO       horas_semanais_trabalho_domestico -0.186379 -0.120006
# RR       horas_semanais_trabalho_domestico -0.195324 -0.161219
# RS       horas_semanais_trabalho_domestico -0.200684 -0.141090
# SC       horas_semanais_trabalho_domestico -0.218684 -0.151889
# SE       horas_semanais_trabalho_domestico -0.189876 -0.149676
# SP       horas_semanais_trabalho_domestico -0.200162 -0.142638
# TO       horas_semanais_trabalho_domestico -0.192517 -0.144841
#
#                                             horas_semanais_trabalho_domestico
# sigla_uf
# AC       horas_semanais_trabalho_domestico                                1.0
# AL       horas_semanais_trabalho_domestico                                1.0
# AM       horas_semanais_trabalho_domestico                                1.0
# AP       horas_semanais_trabalho_domestico                                1.0
# BA       horas_semanais_trabalho_domestico                                1.0
# CE       horas_semanais_trabalho_domestico                                1.0
# DF       horas_semanais_trabalho_domestico                                1.0
# ES       horas_semanais_trabalho_domestico                                1.0
# GO       horas_semanais_trabalho_domestico                                1.0
# MA       horas_semanais_trabalho_domestico                                1.0
# MG       horas_semanais_trabalho_domestico                                1.0
# MS       horas_semanais_trabalho_domestico                                1.0
# MT       horas_semanais_trabalho_domestico                                1.0
# PA       horas_semanais_trabalho_domestico                                1.0
# PB       horas_semanais_trabalho_domestico                                1.0
# PE       horas_semanais_trabalho_domestico                                1.0
# PI       horas_semanais_trabalho_domestico                                1.0
# PR       horas_semanais_trabalho_domestico                                1.0
# RJ       horas_semanais_trabalho_domestico                                1.0
# RN       horas_semanais_trabalho_domestico                                1.0
# RO       horas_semanais_trabalho_domestico                                1.0
# RR       horas_semanais_trabalho_domestico                                1.0
# RS       horas_semanais_trabalho_domestico                                1.0
# SC       horas_semanais_trabalho_domestico                                1.0
# SE       horas_semanais_trabalho_domestico                                1.0
# SP       horas_semanais_trabalho_domestico                                1.0
# TO       horas_semanais_trabalho_domestico                                1.0

# %%
relacao_nota_trabalho_domestico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316524 entries, 0 to 316523
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sexo                               316524 non-null  object
#  1   nota_ct                            316524 non-null  float64
#  2   nota_ch                            316524 non-null  float64
#  3   nota_lc                            316524 non-null  float64
#  4   nota_mt                            316524 non-null  float64
#  5   sigla_uf                           316524 non-null  object
#  6   media                              316524 non-null  float64
#  7   horas_semanais_trabalho_domestico  316524 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 19.3+ MB

# %%
ax = sns.scatterplot(data=relacao_nota_trabalho_domestico, x='horas_semanais_trabalho_domestico', y='media', hue='sexo')

sns.set(rc={'figure.figsize':(15,10)})
ax.set(title ='Distribuição da media do ENEM com base nas horas semanais médias trabalhadas em casa por estado e gênero', 
       xlabel='Quantidade de horas dedicadas a afazeres domésticos na semana estudada', ylabel='Média simples da nota do ENEM')
# Out:
# [Text(0.5, 1.0, 'Distribuição da media do ENEM com base nas horas semanais médias trabalhadas em casa por estado e gênero'),
#  Text(0.5, 0, 'Quantidade de horais de afazeres domésticos dedicadas na semana estudada'),
#  Text(0, 0.5, 'Média simples da nota do ENEM')]

# %% [markdown]
# ###  Minha hipótese era de que as notas mais baixas por parte da média das mulheres em relação aos homens era porque, no Brasil, mulheres dedicam mais horas com afazeres domésticos do que homens. Porém, como foi evidenciado no gráfico acima, a quantidade média de horas por estado não é suficiente para explicar a diferença das notas. Talvez se pudesse ser analisado individualmente a quantidade que cada pessoa levou se dedicando a afazeres doméstiocs ao invés de uma média generalista, o resultado fosse diferente. Porém, não foi o caso, então nada podemos concluir a partir disso

# %% [markdown]
# # Correlacionar renda com sucesso

# %%
enem_2019_renda_mensal = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019.csv',
                                     sep = ',', usecols = ['renda_mensal_familiar', 'treineiro', 'nota_lc', 'nota_mt', 'nota_ct',
                                                           'nota_ch'],
                                     skiprows = lambda i: i > 0 and random.random() > 0.1)

# %%
enem_2019_renda_mensal = enem_2019_renda_mensal.drop(enem_2019_renda_mensal[enem_2019_renda_mensal.treineiro == 1].index)
enem_2019_renda_mensal = enem_2019_renda_mensal.drop(columns = 'treineiro').rename(columns = {'estado': 'sigla_uf'}).dropna()
enem_2019_renda_mensal
# Out:
#        renda_mensal_familiar  nota_ct  nota_ch  nota_lc  nota_mt
# 0        7984.00 até 8982.00    557.8    550.1    528.0    418.5
# 2         998.00 até 1497.00    462.2    499.9    438.0    477.9
# 3                  <= 998.00    422.1    534.4    516.3    585.2
# 4              Nenhuma Renda    484.7    530.8    591.5    459.1
# 5         998.00 até 1497.00    624.0    560.3    565.9    664.7
# ...                      ...      ...      ...      ...      ...
# 509420   6986.00 até 7984.00    486.2    543.4    560.3    535.2
# 509421   3992.00 até 4990.00    500.8    563.2    555.3    442.8
# 509422   1996.00 até 2495.00    514.8    453.7    531.1    491.1
# 509423             <= 998.00    456.6    419.2    447.2    446.5
# 509424             <= 998.00    486.7    457.8    506.7    488.5
#
# [317680 rows x 5 columns]

# %%
enem_2019_renda_mensal.renda_mensal_familiar.unique()
# Out:
# array(['<= 998.00', '3992.00 até 4990.00', '998.00 até 1497.00',
#        '7984.00 até 8982.00', 'Nenhuma Renda', '1996.00 até 2495.00',
#        '1497.00 até 1996.00', '4990.00 até 5988.00',
#        '2495.00 até 2994.00', '8982.00 até 9980.00',
#        '2994.00 até 3992.00', '5988.00 até 6986.00', '>= 19960.00',
#        '6986.00 até 7984.00', '9980.00 até 11976.00',
#        '14970.00 até 19960.00', '11976.00 até 14970.00'], dtype=object)

# %%
enem_2019_renda_mensal.renda_mensal_familiar.nunique()
# Out:
# 17

# %%
enem_2019_renda = enem_2019_renda_mensal.replace({'Nenhuma Renda': 0, '<= 998.00': 1, '998.00 até 1497.00': 2, 
                                                      '1497.00 até 1996.00': 3, '1996.00 até 2495.00': 4,
                                                      '2495.00 até 2994.00': 5, '2994.00 até 3992.00': 6,
                                                      '3992.00 até 4990.00': 7, '4990.00 até 5988.00': 8,
                                                      '5988.00 até 6986.00': 9, '6986.00 até 7984.00': 10,
                                                      '7984.00 até 8982.00': 11, '8982.00 até 9980.00': 12,
                                                      '9980.00 até 11976.00': 13, '11976.00 até 14970.00': 14,
                                                      '14970.00 até 19960.00': 15, '>= 19960.00': 16}
                                                    )
enem_2019_renda
enem_2019_renda.to_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019_renda.csv',
                           sep=';', index=False, encoding='utf-8-sig')

# %%
enem_2019_renda = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019_renda.csv',
                           sep=';', encoding='utf-8-sig')
enem_2019_renda
# Out:
#         renda_mensal_familiar  nota_ct  nota_ch  nota_lc  nota_mt
# 0                          11    557.8    550.1    528.0    418.5
# 1                           2    462.2    499.9    438.0    477.9
# 2                           1    422.1    534.4    516.3    585.2
# 3                           0    484.7    530.8    591.5    459.1
# 4                           2    624.0    560.3    565.9    664.7
# ...                       ...      ...      ...      ...      ...
# 317675                     10    486.2    543.4    560.3    535.2
# 317676                      7    500.8    563.2    555.3    442.8
# 317677                      4    514.8    453.7    531.1    491.1
# 317678                      1    456.6    419.2    447.2    446.5
# 317679                      1    486.7    457.8    506.7    488.5
#
# [317680 rows x 5 columns]

# %%
ax = sns.displot(enem_2019_renda['renda_mensal_familiar'], height=8)

ax.set(title ='Distribuição de frequência da renda mensal', 
       xlabel='Categoria da renda mensal', ylabel='Quantidade de participantes')

# %%
enem_2019_renda.corr()
# Out:
#                        renda_mensal_familiar   nota_ct   nota_ch   nota_lc  \
# renda_mensal_familiar               1.000000  0.439815  0.414373  0.402924
# nota_ct                             0.439815  1.000000  0.672637  0.644008
# nota_ch                             0.414373  0.672637  1.000000  0.747750
# nota_lc                             0.402924  0.644008  0.747750  1.000000
# nota_mt                             0.468615  0.650664  0.613612  0.591320
#
#                         nota_mt
# renda_mensal_familiar  0.468615
# nota_ct                0.650664
# nota_ch                0.613612
# nota_lc                0.591320
# nota_mt                1.000000

# %% [markdown]
# ### Explicação

# %% [markdown]
# # Escola pública vs privada

# %%
idep_uf = bd.read_table(dataset_id='br_inep_ideb', table_id='uf', billing_project_id="analytica-desigualdade")
idep_uf.drop(columns = "indicador_rendimento", inplace = True) #é a mesma coisa que a taxa de aprovação!
# Out:
# Downloading: 100%|██████████| 2629/2629 [00:00<00:00, 2799.20rows/s]

# %%
idep_2019
# Out:
#      sigla_uf      rede  taxa_aprovacao  nota_saeb_matematica  \
# 2081       AC  estadual            81.8                265.72
# 2084       AC   privada            96.8                334.38
# 2089       AC     total            82.8                270.17
# 2092       AL  estadual            86.0                255.24
# 2095       AL   privada            95.3                304.00
# ...       ...       ...             ...                   ...
# 2359       SP   privada            97.7                336.10
# 2364       SP     total            92.3                283.92
# 2367       TO  estadual            87.7                264.14
# 2370       TO   privada            94.9                341.20
# 2375       TO     total            87.9                269.19
#
#       nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2081                       268.17                     4.436058   3.7       4.6
# 2084                       329.85                     6.323886   6.1       6.9
# 2089                       272.11                     4.557830   3.9       4.8
# 2092                       260.64                     4.176142   3.6       4.4
# 2095                       302.14                     5.482231   5.2       5.9
# ...                           ...                          ...   ...       ...
# 2359                       323.54                     6.253723   6.1       7.0
# 2364                       286.54                     4.966816   4.6       5.2
# 2367                       262.85                     4.334516   3.9       4.5
# 2370                       321.69                     6.297368   6.0       6.7
# 2375                       266.70                     4.462937   4.0       4.7
#
# [81 rows x 8 columns]

# %%
idep_uf_2019 = idep_uf.query("ano == 2019").drop(columns = 'ano')
idep_2019_total = idep_uf_2019.query("anos_escolares == 'todos (1-4)'").drop(columns = ['anos_escolares', 'ensino'])
idep_2019_total = idep_2019_total.query("rede != 'total'")
idep_2019_total
# Out:
#      sigla_uf      rede  taxa_aprovacao  nota_saeb_matematica  \
# 2081       AC  estadual            81.8                265.72
# 2084       AC   privada            96.8                334.38
# 2092       AL  estadual            86.0                255.24
# 2095       AL   privada            95.3                304.00
# 2103       AM  estadual            82.3                248.71
# 2106       AM   privada            96.0                308.54
# 2114       AP  estadual            76.7                248.72
# 2117       AP   privada            97.7                301.70
# 2125       BA  estadual            77.5                253.02
# 2128       BA   privada            95.6                328.30
# 2136       CE  estadual            92.4                266.07
# 2139       CE   privada            96.6                322.88
# 2147       DF  estadual            82.9                276.57
# 2150       DF   privada            96.4                345.35
# 2158       ES  estadual            87.6                289.14
# 2161       ES   privada            96.5                354.80
# 2169       GO  estadual            92.4                282.92
# 2172       GO   privada            96.6                338.01
# 2180       MA  estadual            90.5                249.77
# 2183       MA   privada            94.8                315.04
# 2191       MG  estadual            82.8                278.73
# 2194       MG   privada            95.7                355.04
# 2202       MS  estadual            81.1                278.13
# 2205       MS   privada            96.6                338.29
# 2213       MT  estadual            70.1                263.72
# 2216       MT   privada            97.1                337.95
# 2224       PA  estadual            76.8                246.08
# 2227       PA   privada            97.0                324.97
# 2235       PB  estadual            80.6                261.51
# 2238       PB   privada            95.6                330.75
# 2246       PE  estadual            93.6                272.76
# 2249       PE   privada            95.8                330.97
# 2257       PI  estadual            83.3                260.92
# 2260       PI   privada            95.3                338.41
# 2268       PR  estadual            87.6                280.79
# 2271       PR   privada            97.2                350.73
# 2279       RJ  estadual            78.1                265.29
# 2282       RJ   privada            94.4                323.14
# 2290       RN  estadual            73.5                250.86
# 2293       RN   privada            94.5                319.55
# 2301       RO  estadual            85.3                275.89
# 2304       RO   privada            94.1                323.89
# 2312       RR  estadual            82.3                258.79
# 2315       RR   privada            96.1                333.48
# 2323       RS  estadual            76.5                282.16
# 2326       RS   privada            95.9                337.92
# 2334       SC  estadual            79.2                279.57
# 2337       SC   privada            96.5                343.54
# 2345       SE  estadual            78.1                259.04
# 2348       SE   privada            95.2                322.60
# 2356       SP  estadual            91.1                273.45
# 2359       SP   privada            97.7                336.10
# 2367       TO  estadual            87.7                264.14
# 2370       TO   privada            94.9                341.20
#
#       nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2081                       268.17                     4.436058   3.7       4.6
# 2084                       329.85                     6.323886   6.1       6.9
# 2092                       260.64                     4.176142   3.6       4.4
# 2095                       302.14                     5.482231   5.2       5.9
# 2103                       255.97                     4.014518   3.5       3.8
# 2106                       310.70                     5.674279   5.5       6.5
# 2114                       256.64                     4.024689   3.2       4.3
# 2117                       299.51                     5.410697   5.3       6.3
# 2125                       256.94                     4.089573   3.2       4.3
# 2128                       319.76                     6.087436   5.9       6.7
# 2136                       270.42                     4.474796   4.2       4.5
# 2139                       315.20                     5.942909   5.7       6.8
# 2147                       279.04                     4.751320   4.0       4.6
# 2150                       326.01                     6.420615   6.2       7.1
# 2158                       286.95                     5.046128   4.6       4.7
# 2161                       330.38                     6.618609   6.3       6.9
# 2169                       285.35                     4.934957   4.7       4.4
# 2172                       320.04                     6.228004   6.0       7.0
# 2180                       256.57                     4.038388   3.7       4.0
# 2183                       312.25                     5.788635   5.5       6.1
# 2191                       277.83                     4.763683   4.0       5.0
# 2194                       333.52                     6.669136   6.4       7.3
# 2202                       279.42                     4.778918   4.1       4.5
# 2205                       323.30                     6.280748   6.1       7.0
# 2213                       265.98                     4.375183   3.4       4.2
# 2216                       322.01                     6.256652   6.1       6.6
# 2224                       252.83                     3.930724   3.2       4.2
# 2227                       319.67                     6.039179   5.9       6.4
# 2235                       266.23                     4.348177   3.6       4.2
# 2238                       318.29                     6.099849   5.9       6.4
# 2246                       276.29                     4.656781   4.4       4.3
# 2249                       319.73                     6.124347   5.9       6.6
# 2257                       262.29                     4.280908   3.7       3.8
# 2260                       325.39                     6.313571   6.0       6.8
# 2268                       281.76                     4.851448   4.4       4.9
# 2271                       332.55                     6.594081   6.4       7.0
# 2279                       268.79                     4.439300   3.5       4.4
# 2282                       315.07                     5.944755   5.7       6.5
# 2290                       255.32                     4.034985   3.2       4.2
# 2293                       314.89                     5.891788   5.6       6.5
# 2301                       275.79                     4.693116   4.0       4.5
# 2304                       316.02                     5.969660   5.6       6.4
# 2312                       262.39                     4.252199   3.5       4.8
# 2315                       324.04                     6.224410   6.0       6.2
# 2323                       282.98                     4.888663   4.0       5.0
# 2326                       323.63                     6.280342   6.1       7.0
# 2334                       276.89                     4.761409   3.8       5.1
# 2337                       324.45                     6.371691   6.2       7.0
# 2345                       261.77                     4.246579   3.3       4.4
# 2348                       315.35                     5.941371   5.7       6.8
# 2356                       279.11                     4.708547   4.3       4.9
# 2359                       323.54                     6.253723   6.1       7.0
# 2367                       262.85                     4.334516   3.9       4.5
# 2370                       321.69                     6.297368   6.0       6.7

# %%
ax = sns.displot(data=idep_2019_total, x='nota_saeb_media_padronizada', hue='rede', kind='kde')
ax.set(title ='Comparação entre desempenho médio no IDEP 2019 das escolas da rede estadual e privada', 
       xlabel='Nota média', ylabel='Densidade')

# %% [markdown]
# # Capital vs Interior

# %%
enem_2019 = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Documentos\Ciência_da_Computação\Analytica\Dados\enem_2019.csv', sep = ',',
                        usecols = ['treineiro', 'nota_lc', 'nota_mt', 'nota_ct', 'nota_ch', 'municipio'],
                        skiprows = lambda i: i > 0 and random.random() > 0.1)
enem_2019
# Out:
#         treineiro  nota_ct  nota_ch  nota_lc  nota_mt            municipio
# 0               1    443.5    432.4    515.3    397.0  SÃO MIGUEL DO GUAMÁ
# 1               0    682.0    669.1    640.9    801.9                BELÉM
# 2               0    343.8    481.0    499.5    397.6           ANANINDEUA
# 3               0    496.8    475.1    544.9    537.8  SANTA MARIA DO PARÁ
# 4               0      NaN      NaN      NaN      NaN                BELÉM
# ...           ...      ...      ...      ...      ...                  ...
# 508287          0    524.0    639.2    591.4    637.5              UBERABA
# 508288          0    399.4    446.2    521.2    426.0  ENTRE RIOS DE MINAS
# 508289          0      NaN      NaN      NaN      NaN            CARATINGA
# 508290          0    523.1    395.3    512.0    464.5     CLARO DOS POÇÕES
# 508291          0    456.6    419.2    447.2    446.5              ITURAMA
#
# [508292 rows x 6 columns]

# %%
enem_2019 = enem_2019.drop(enem_2019[enem_2019.treineiro == 1].index) #removendo os treineiros ;)
enem_2019.drop(columns = 'treineiro', inplace = True)
enem_2019['media'] = (enem_2019.nota_ct + enem_2019.nota_ch + enem_2019.nota_mt + enem_2019.nota_lc)/4
enem_2019.dropna(inplace=True)
enem_2019
# Out:
#         nota_ct  nota_ch  nota_lc  nota_mt            municipio    media
# 1         682.0    669.1    640.9    801.9                BELÉM  698.475
# 2         343.8    481.0    499.5    397.6           ANANINDEUA  430.475
# 3         496.8    475.1    544.9    537.8  SANTA MARIA DO PARÁ  513.650
# 4           NaN      NaN      NaN      NaN                BELÉM      NaN
# 5           NaN      NaN      NaN      NaN           ABAETETUBA      NaN
# ...         ...      ...      ...      ...                  ...      ...
# 508287    524.0    639.2    591.4    637.5              UBERABA  598.025
# 508288    399.4    446.2    521.2    426.0  ENTRE RIOS DE MINAS  448.200
# 508289      NaN      NaN      NaN      NaN            CARATINGA      NaN
# 508290    523.1    395.3    512.0    464.5     CLARO DOS POÇÕES  473.725
# 508291    456.6    419.2    447.2    446.5              ITURAMA  442.375
#
# [446532 rows x 6 columns]

# %%
capitais = ['JOÃO PESSOA', 'RIO DE JANEIRO', 'NATAL', 'RECIFE', 'TERESINA', 'BELÉM', 'PORTO VELHO', 'MANAUS', 'CUIABÁ', 'PALMAS',
            'SÃO PAULO', 'BRASÍLIA',  'SALVADOR', 'MACAPÁ', 'BOA VISTA', 'RIO BRANCO', 'CAMPO GRANDE', 'VITÓRIA', 'SÃO LUÍS', 
            'MACEIÓ', 'PORTO ALEGRE', 'CURITIBA', 'BELO HORIZONTE', 'FORTALEZA', 'FLORIANÓPOLIS', 'ARACAJU', 'GOIÂNIA']
enem_2019_capitais = enem_2019.query('municipio == @capitais')
enem_2019_interior = enem_2019.query('municipio != @capitais')
enem_2019_capitais.municipio.nunique()
# Out:
# 27

# %%
print(f"Capitais: \n{enem_2019_capitais.media.describe()}\n\nInterior: \n{enem_2019_interior.media.describe()}")
# Out:
# Capitais:
# count    94320.000000
# mean       517.651975
# std         75.329621
# min          0.000000
# 25%        459.250000
# 50%        506.425000
# 75%        568.675000
# max        818.525000
# Name: media, dtype: float64
#
# Interior:
# count    222302.000000
# mean        502.731343
# std          68.488323
# min           0.000000
# 25%         450.275000
# 50%         492.425000
# 75%         547.300000
# max         795.775000
# Name: media, dtype: float64

# %%
enem_2019_capitais.media.describe() - enem_2019_interior.media.describe()
# Out:
# count   -127982.000000
# mean         14.920633
# std           6.841298
# min           0.000000
# 25%           8.975000
# 50%          14.000000
# 75%          21.375000
# max          22.750000
# Name: media, dtype: float64

# %%
enem_2019_capitais.municipio.nunique() / (enem_2019.municipio.nunique())*100
# Out:
# 0.5191309363583926

# %%
enem_2019_capitais.municipio.count() / (enem_2019.municipio.count())*100
# Out:
# 29.789465040332004

# %% [markdown]
# ### Conclusão: Apesar das capitais brasileiras representarem 0.51% das cidades do Brasil, seus candidatos representam 29.64%, uma diferença de 29.13 pontos percentuais, indicando que
# (!!!) Mais pessoas moram nas capitais lol (!!!)

# %%
_, p_valor = sp.normaltest(enem_2019.media)
if p_valor > 0.05:
    print("A média se distribui como uma variável normal")
else:
    print("A média não se distribui como uma variável normal")
# Out:
# A média não se distribui como uma variável normal

# %%
#H0: não existe diferença na média dos alunos da capital em relação ao interior (media_capital == media_interior)
#H1: a média dos alunos da capital é maior que a média dos alunos do interior   (media_capital != media_interior)
u, p_valor = sp.mannwhitneyu(enem_2019_capitais.media, enem_2019_interior.media, alternative = 'greater')
if p_valor <= 0.05:
    print("A média dos alunos da capital é significativamente maior do que a dos alunos do interior")
else:
    print("Não existe diferença significativa entre esses dois grupos")
# Out:
# A média dos alunos da capital é significativamente maior do que a dos alunos do interior

# %% [markdown]
# ### Conclusão: Rejeitamos a hipótese de que não existe diferença na média dos alunos da capital em relação ao interior, isto é, concluimos que a média dos alunos da capital é significativamente maior do que a dos alunos do interior.
